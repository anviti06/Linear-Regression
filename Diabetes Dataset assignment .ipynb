# %%
#Import
from sklearn import datasets
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn import model_selection
alg1 = LinearRegression()

# %%
#Importing Given train.csv File
data_train = np.genfromtxt("train.csv" , delimiter =",")
x = data[:,0].reshape(-1,1)
y = data[:,1]
# Out:
# (331, 1)

# %%
#Separating Test and Train Data
from sklearn import model_selection
x_train, x_test, y_train, y_test = model_selection.train_test_split(x, y)

# %%
#Applying LinearRegression Algo on Train Data
alg1.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
#Getting Predictions
y_pred = alg1.predict(x_test)

# %%
#Plotting Gpraph
m = alg1.coef_[0]
c = alg1.intercept_
y = m * x + c
x = np.arange(-0.06,0.05,0.001)
plt.plot(x,y, "r")
plt.scatter(y_pred, y_test)
plt.show()

# %%
#Testing for given test.csv file
data_given_test = np.genfromtxt("test.csv" , delimiter =",")
x_given_test = data[:,0].reshape(-1,1)
y_given_test = data[:,1]
y_test_pred = alg1.predict(x_given_test)

#Plotting Graph for given Test.csv File
m = alg1.coef_[0]
c = alg1.intercept_
y = m * x + c
x = np.arange(-0.05,0.06,0.001)

plt.scatter(y_test_pred, y_given_test)
plt.plot(x,y,"r")
plt.show()

# %%
#Getting score
score_test1 = alg1.score(x_train , y_train)
score_test2 = alg1.score(x_given_test , y_given_test)
print("Score of Training Data is : " ,score_test1)
print("Score of Testing Data is : " ,score_test2)
# Out:
# Score of Training Data is :  0.03652825284287542
# Score of Testing Data is :  0.04665469938910006

# %%
p = np.savetxt('final_predictions.csv', y_test_pred, delimiter =', ')    
a = open("final_predictions.csv", 'r')# open file in read mode 
  
print("the file contains:") 
print(a.read())
# Out:
# the file contains:
# -1.013000000000000012e-02
# -1.404999999999999999e-02
# -9.899999999999999946e-04
# 7.499999999999999722e-03
# 6.190000000000000190e-03
# -1.209000000000000005e-02
# -1.469999999999999953e-02
# -4.250000000000000305e-03
# 2.929999999999999879e-03
# 1.207000000000000087e-02
# 4.230000000000000253e-03
# -3.400000000000000244e-04
# -7.519999999999999775e-03
# -4.250000000000000305e-03
# -3.400000000000000244e-04
# 1.010999999999999920e-02
# -8.819999999999999715e-03
# -6.210000000000000242e-03
# 1.619999999999999912e-03
# -1.535000000000000080e-02
# -2.949999999999999931e-03
# 1.619999999999999912e-03
# -1.862000000000000113e-02
# -1.992000000000000021e-02
# -1.639999999999999965e-03
# 1.076000000000000047e-02
# -6.210000000000000242e-03
# 6.190000000000000190e-03
# 6.839999999999999726e-03
# 3.200000000000000262e-04
# -1.666000000000000120e-02
# -1.469999999999999953e-02
# -9.480000000000000579e-03
# 1.336999999999999994e-02
# -8.170000000000000179e-03
# ...
